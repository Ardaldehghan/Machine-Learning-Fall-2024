# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Amirardalan Dehghanpour
# Student-ID: 401105901

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)


def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train,x_test,y_train,y_test = train_test_split(
    x, y_new, train_size=60000, random_state=42)
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # -------------------------------- TODO -------------------------------------
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        # Do the same for other activation functions

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}
        self.grads = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return (x > 0).astype(float)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - np.tanh(x)**2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        sig = 1 / (1 + np.exp(-x))
        if derivative:
          return sig * (1 - sig)
        else:
          return sig
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exp_x = np.exp(x - np.max(x, axis=0, keepdims=True))
        return exp_x / np.sum(exp_x, axis=0, keepdims=True)
        # -------------------------------- TODO -------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
         return np.where(x > 0, 1, alpha)
        else:
         return np.where(x > 0, x, alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
         return np.where(x > 0, 1, alpha * np.exp(x))
        else:
         return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
         return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
         return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
           z = self.params[f"W{i}"] @ self.cache[f"A{i-1}"] + self.params[f"b{i}"]
           self.cache[f"Z{i}"] = z
           if i == self.num_layers:  # Output layer uses softmax
             softmax_output = self.softmax(z)
             self.cache[f"A{i}"] = (softmax_output == np.max(softmax_output, axis=0, keepdims=True)).astype(float)
           else:  # Hidden layers use the selected activation
            self.cache[f"A{i}"] = self.activation(z)
        return self.cache[f"A{self.num_layers}"]

        # -------------------------------- TODO -------------------------------------


    def back_propagate(self, y, output):
        m = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        dz = output - y.T
        for i in range(self.num_layers, 0, -1):
            self.grads[f"dW{i}"] = dz @ self.cache[f"A{i-1}"].T / m
            self.grads[f"db{i}"] = np.sum(dz, axis=1, keepdims=True) / m
            if i > 1:
                da = self.params[f"W{i}"].T @ dz
                dz = da * self.activation(self.cache[f"Z{i-1}"], derivative=True)
        return self.grads
        # -------------------------------- TODO -------------------------------------



    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        m = y.shape[0]
        loss = -np.sum(y * np.log(output.T + 1e-8)) / m  # Add a small constant for numerical stability
        return loss
        # -------------------------------- TODO -------------------------------------

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
         momemtum_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])  # Velocity for weights
         momemtum_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])  # Velocity for biases
        return momemtum_opt
            # -------------------------------- TODO -------------------------------------

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
          adam_opt[f"m_W{i}"] = np.zeros_like(self.params[f"W{i}"])  # First moment for weights
          adam_opt[f"m_b{i}"] = np.zeros_like(self.params[f"b{i}"])  # First moment for biases
          adam_opt[f"v_W{i}"] = np.zeros_like(self.params[f"W{i}"])  # Second moment for weights
          adam_opt[f"v_b{i}"] = np.zeros_like(self.params[f"b{i}"])  # Second moment for biases
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[f"d{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
             self.momemtum_opt[f"v{key}"] = beta * self.momemtum_opt[f"v{key}"] + (1 - beta) * self.grads[f"d{key}"]
             self.params[key] -= l_rate * self.momemtum_opt[f"v{key}"]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                self.adam_opt[f"m_{key}"] = beta1 * self.adam_opt[f"m_{key}"] + (1 - beta1) * self.grads[f"d{key}"]
                self.adam_opt[f"v_{key}"] = beta2 * self.adam_opt[f"v_{key}"] + (1 - beta2) * (self.grads[f"d{key}"] ** 2)
                m_hat = self.adam_opt[f"m_{key}"] / (1 - beta1**t)
                v_hat = self.adam_opt[f"v_{key}"] / (1 - beta2**t)
                self.params[key] -= l_rate * m_hat / (np.sqrt(v_hat) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        predictions = np.argmax(output, axis=0)
        labels = np.argmax(y, axis=1)
        return np.mean(predictions == labels)
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=128, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]
            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')
        return test_acc,test_loss

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...
optimizers = ["sgd", "momentum", "adam"]
activations = ["relu", "sigmoid", "tanh", "leaky_relu", "selu", "elu"]
learning_rates = [0.01, 0.001]
sizes=[x_train.shape[1],128,64,10]
epochs = 20
results=[]
for optimizer in optimizers:
  for activation in activations:
    for lr in learning_rates:
        print(f"Optimizer={optimizer}, Activation={activation}, LR={lr}")
        model = MLP(sizes, activation=activation)
        model.train(
                    x_train, y_train, x_test, y_test,
                    epochs=epochs, batch_size=128,
                    optimizer=optimizer, l_rate=lr
         )
        acc,loss=model.evaluate(x_test, y_test)
        results.append((sizes, optimizer, activation, lr, acc, loss))

results.sort(key=lambda x: -x[4])
for res in results:
    print(f"Arch={res[0]}, Optimizer={res[1]}, Activation={res[2]}, LR={res[3]} -> Acc={res[4]:.2f}, Loss={res[5]:.2f}")
# Out:
# Optimizer=sgd, Activation=relu, LR=0.01
# Epoch 1: 2.81s, train acc=0.65, train loss=6.47, validation acc=0.64, validation loss=6.68
# Epoch 2: 5.85s, train acc=0.71, train loss=5.28, validation acc=0.70, validation loss=5.44
# Epoch 3: 10.60s, train acc=0.74, train loss=4.80, validation acc=0.74, validation loss=4.87
# Epoch 4: 13.24s, train acc=0.76, train loss=4.36, validation acc=0.76, validation loss=4.48
# Epoch 5: 15.83s, train acc=0.78, train loss=4.09, validation acc=0.77, validation loss=4.23
# Epoch 6: 18.48s, train acc=0.79, train loss=3.87, validation acc=0.78, validation loss=4.01
# Epoch 7: 23.04s, train acc=0.80, train loss=3.76, validation acc=0.79, validation loss=3.96
# Epoch 8: 26.03s, train acc=0.80, train loss=3.63, validation acc=0.79, validation loss=3.85
# Epoch 9: 28.69s, train acc=0.81, train loss=3.56, validation acc=0.80, validation loss=3.77
# Epoch 10: 31.36s, train acc=0.81, train loss=3.45, validation acc=0.80, validation loss=3.66
# Epoch 11: 34.11s, train acc=0.82, train loss=3.40, validation acc=0.80, validation loss=3.61
# Epoch 12: 39.45s, train acc=0.82, train loss=3.36, validation acc=0.81, validation loss=3.53
# Epoch 13: 42.07s, train acc=0.82, train loss=3.33, validation acc=0.81, validation loss=3.54
# Epoch 14: 44.60s, train acc=0.82, train loss=3.26, validation acc=0.81, validation loss=3.53
# Epoch 15: 47.32s, train acc=0.83, train loss=3.22, validation acc=0.81, validation loss=3.44
# Epoch 16: 51.00s, train acc=0.83, train loss=3.21, validation acc=0.81, validation loss=3.42
# Epoch 17: 55.20s, train acc=0.83, train loss=3.19, validation acc=0.81, validation loss=3.43
# Epoch 18: 57.92s, train acc=0.83, train loss=3.17, validation acc=0.81, validation loss=3.43
# Epoch 19: 60.52s, train acc=0.83, train loss=3.20, validation acc=0.81, validation loss=3.47
# Epoch 20: 63.23s, train acc=0.83, train loss=3.15, validation acc=0.81, validation loss=3.48
#
# Test acc=0.81, Test loss=3.48
# Optimizer=sgd, Activation=relu, LR=0.001
# Epoch 1: 5.06s, train acc=0.30, train loss=12.81, validation acc=0.31, validation loss=12.78
# Epoch 2: 7.67s, train acc=0.43, train loss=10.49, validation acc=0.43, validation loss=10.58
# Epoch 3: 10.49s, train acc=0.51, train loss=9.08, validation acc=0.50, validation loss=9.18
# Epoch 4: 13.05s, train acc=0.56, train loss=8.18, validation acc=0.56, validation loss=8.16
# Epoch 5: 16.70s, train acc=0.59, train loss=7.47, validation acc=0.59, validation loss=7.51
# Epoch 6: 20.91s, train acc=0.62, train loss=6.95, validation acc=0.62, validation loss=6.94
# Epoch 7: 23.70s, train acc=0.65, train loss=6.52, validation acc=0.65, validation loss=6.47
# Epoch 8: 26.39s, train acc=0.66, train loss=6.18, validation acc=0.66, validation loss=6.18
# Epoch 9: 28.87s, train acc=0.68, train loss=5.88, validation acc=0.68, validation loss=5.90
# Epoch 10: 34.53s, train acc=0.69, train loss=5.65, validation acc=0.70, validation loss=5.62
# Epoch 11: 37.33s, train acc=0.71, train loss=5.40, validation acc=0.71, validation loss=5.41
# Epoch 12: 40.07s, train acc=0.72, train loss=5.23, validation acc=0.72, validation loss=5.24
# Epoch 13: 42.75s, train acc=0.73, train loss=5.07, validation acc=0.72, validation loss=5.09
# Epoch 14: 46.52s, train acc=0.73, train loss=4.90, validation acc=0.73, validation loss=4.94
# Epoch 15: 50.68s, train acc=0.74, train loss=4.77, validation acc=0.74, validation loss=4.82
# Epoch 16: 53.30s, train acc=0.75, train loss=4.64, validation acc=0.74, validation loss=4.70
# Epoch 17: 55.71s, train acc=0.75, train loss=4.55, validation acc=0.75, validation loss=4.64
# Epoch 18: 58.24s, train acc=0.76, train loss=4.44, validation acc=0.75, validation loss=4.53
# Epoch 19: 63.17s, train acc=0.76, train loss=4.36, validation acc=0.76, validation loss=4.42
# Epoch 20: 66.06s, train acc=0.77, train loss=4.26, validation acc=0.76, validation loss=4.34
#
# Test acc=0.76, Test loss=4.34
# Optimizer=sgd, Activation=sigmoid, LR=0.01
# Epoch 1: 3.49s, train acc=0.33, train loss=12.26, validation acc=0.33, validation loss=12.35
# Epoch 2: 6.97s, train acc=0.53, train loss=8.66, validation acc=0.53, validation loss=8.71
# Epoch 3: 12.96s, train acc=0.65, train loss=6.41, validation acc=0.65, validation loss=6.37
# Epoch 4: 16.22s, train acc=0.63, train loss=6.89, validation acc=0.63, validation loss=6.82
# Epoch 5: 19.51s, train acc=0.64, train loss=6.67, validation acc=0.65, validation loss=6.54
# Epoch 6: 22.81s, train acc=0.74, train loss=4.70, validation acc=0.75, validation loss=4.69
# Epoch 7: 28.57s, train acc=0.70, train loss=5.44, validation acc=0.69, validation loss=5.63
# Epoch 8: 32.07s, train acc=0.78, train loss=4.06, validation acc=0.78, validation loss=4.07
# Epoch 9: 35.73s, train acc=0.75, train loss=4.59, validation acc=0.75, validation loss=4.54
# Epoch 10: 40.61s, train acc=0.80, train loss=3.77, validation acc=0.79, validation loss=3.80
# Epoch 11: 44.71s, train acc=0.79, train loss=3.90, validation acc=0.79, validation loss=3.89
# Epoch 12: 48.20s, train acc=0.79, train loss=3.80, validation acc=0.79, validation loss=3.84
# Epoch 13: 51.62s, train acc=0.80, train loss=3.70, validation acc=0.80, validation loss=3.72
# Epoch 14: 57.58s, train acc=0.81, train loss=3.49, validation acc=0.81, validation loss=3.45
# Epoch 15: 61.01s, train acc=0.77, train loss=4.27, validation acc=0.77, validation loss=4.32
# Epoch 16: 64.42s, train acc=0.82, train loss=3.32, validation acc=0.82, validation loss=3.36
# Epoch 17: 68.96s, train acc=0.83, train loss=3.17, validation acc=0.83, validation loss=3.14
# Epoch 18: 73.73s, train acc=0.81, train loss=3.51, validation acc=0.81, validation loss=3.43
# Epoch 19: 77.28s, train acc=0.83, train loss=3.21, validation acc=0.83, validation loss=3.17
# Epoch 20: 80.84s, train acc=0.83, train loss=3.21, validation acc=0.83, validation loss=3.18
#
# Test acc=0.83, Test loss=3.18
# Optimizer=sgd, Activation=sigmoid, LR=0.001
# Epoch 1: 6.12s, train acc=0.09, train loss=16.83, validation acc=0.08, validation loss=16.95
# Epoch 2: 9.79s, train acc=0.11, train loss=16.47, validation acc=0.10, validation loss=16.59
# Epoch 3: 12.97s, train acc=0.13, train loss=15.95, validation acc=0.13, validation loss=16.04
# Epoch 4: 16.90s, train acc=0.17, train loss=15.27, validation acc=0.17, validation loss=15.37
# Epoch 5: 22.12s, train acc=0.21, train loss=14.52, validation acc=0.20, validation loss=14.67
# Epoch 6: 25.66s, train acc=0.24, train loss=13.92, validation acc=0.24, validation loss=14.06
# Epoch 7: 28.91s, train acc=0.28, train loss=13.31, validation acc=0.27, validation loss=13.45
# Epoch 8: 34.11s, train acc=0.31, train loss=12.67, validation acc=0.30, validation loss=12.84
# Epoch 9: 38.15s, train acc=0.35, train loss=11.93, validation acc=0.34, validation loss=12.10
# Epoch 10: 41.62s, train acc=0.38, train loss=11.46, validation acc=0.37, validation loss=11.59
# Epoch 11: 45.09s, train acc=0.41, train loss=10.92, validation acc=0.40, validation loss=10.97
# Epoch 12: 51.14s, train acc=0.42, train loss=10.59, validation acc=0.42, validation loss=10.76
# Epoch 13: 54.64s, train acc=0.45, train loss=10.16, validation acc=0.44, validation loss=10.33
# Epoch 14: 57.93s, train acc=0.47, train loss=9.70, validation acc=0.47, validation loss=9.81
# Epoch 15: 62.53s, train acc=0.49, train loss=9.45, validation acc=0.48, validation loss=9.53
# Epoch 16: 66.94s, train acc=0.50, train loss=9.28, validation acc=0.49, validation loss=9.40
# Epoch 17: 70.49s, train acc=0.52, train loss=8.92, validation acc=0.51, validation loss=9.05
# Epoch 18: 73.90s, train acc=0.53, train loss=8.61, validation acc=0.52, validation loss=8.76
# Epoch 19: 79.68s, train acc=0.55, train loss=8.33, validation acc=0.54, validation loss=8.45
# Epoch 20: 83.18s, train acc=0.55, train loss=8.35, validation acc=0.54, validation loss=8.42
#
# Test acc=0.54, Test loss=8.42
# Optimizer=sgd, Activation=tanh, LR=0.01
# Epoch 1: 5.04s, train acc=0.81, train loss=3.44, validation acc=0.81, validation loss=3.52
# Epoch 2: 12.65s, train acc=0.85, train loss=2.79, validation acc=0.84, validation loss=2.90
# Epoch 3: 17.83s, train acc=0.86, train loss=2.51, validation acc=0.86, validation loss=2.65
# Epoch 4: 24.01s, train acc=0.87, train loss=2.36, validation acc=0.86, validation loss=2.54
# Epoch 5: 29.45s, train acc=0.88, train loss=2.26, validation acc=0.87, validation loss=2.40
# Epoch 6: 34.56s, train acc=0.88, train loss=2.18, validation acc=0.88, validation loss=2.30
# Epoch 7: 42.16s, train acc=0.88, train loss=2.14, validation acc=0.88, validation loss=2.29
# Epoch 8: 47.26s, train acc=0.89, train loss=2.05, validation acc=0.88, validation loss=2.20
# Epoch 9: 54.42s, train acc=0.89, train loss=1.98, validation acc=0.88, validation loss=2.19
# Epoch 10: 59.54s, train acc=0.89, train loss=2.02, validation acc=0.88, validation loss=2.22
# Epoch 11: 64.52s, train acc=0.89, train loss=1.96, validation acc=0.88, validation loss=2.15
# Epoch 12: 71.52s, train acc=0.89, train loss=1.97, validation acc=0.88, validation loss=2.19
# Epoch 13: 76.50s, train acc=0.90, train loss=1.92, validation acc=0.89, validation loss=2.09
# Epoch 14: 86.62s, train acc=0.90, train loss=1.85, validation acc=0.89, validation loss=2.06
# Epoch 15: 91.89s, train acc=0.90, train loss=1.83, validation acc=0.89, validation loss=2.06
# Epoch 16: 98.31s, train acc=0.90, train loss=1.78, validation acc=0.89, validation loss=2.04
# Epoch 17: 103.40s, train acc=0.90, train loss=1.76, validation acc=0.89, validation loss=2.06
# Epoch 18: 108.31s, train acc=0.90, train loss=1.78, validation acc=0.89, validation loss=2.02
# Epoch 19: 115.64s, train acc=0.91, train loss=1.74, validation acc=0.89, validation loss=2.01
# Epoch 20: 120.68s, train acc=0.90, train loss=1.79, validation acc=0.89, validation loss=2.01
#
# Test acc=0.89, Test loss=2.01
# Optimizer=sgd, Activation=tanh, LR=0.001
# Epoch 1: 6.91s, train acc=0.45, train loss=10.13, validation acc=0.45, validation loss=10.09
# Epoch 2: 12.08s, train acc=0.60, train loss=7.41, validation acc=0.60, validation loss=7.40
# Epoch 3: 17.25s, train acc=0.67, train loss=6.06, validation acc=0.67, validation loss=6.05
# Epoch 4: 24.19s, train acc=0.71, train loss=5.34, validation acc=0.71, validation loss=5.37
# Epoch 5: 29.14s, train acc=0.74, train loss=4.83, validation acc=0.74, validation loss=4.88
# Epoch 6: 36.32s, train acc=0.76, train loss=4.48, validation acc=0.76, validation loss=4.51
# Epoch 7: 41.24s, train acc=0.77, train loss=4.23, validation acc=0.77, validation loss=4.28
# Epoch 8: 46.95s, train acc=0.78, train loss=4.02, validation acc=0.78, validation loss=4.11
# Epoch 9: 53.30s, train acc=0.79, train loss=3.86, validation acc=0.79, validation loss=3.93
# Epoch 10: 58.27s, train acc=0.80, train loss=3.72, validation acc=0.79, validation loss=3.81
# Epoch 11: 65.51s, train acc=0.81, train loss=3.58, validation acc=0.80, validation loss=3.70
# Epoch 12: 70.68s, train acc=0.81, train loss=3.50, validation acc=0.80, validation loss=3.63
# Epoch 13: 76.01s, train acc=0.82, train loss=3.40, validation acc=0.81, validation loss=3.53
# Epoch 14: 82.14s, train acc=0.82, train loss=3.31, validation acc=0.81, validation loss=3.44
# Epoch 15: 87.13s, train acc=0.82, train loss=3.25, validation acc=0.82, validation loss=3.38
# Epoch 16: 94.21s, train acc=0.83, train loss=3.20, validation acc=0.82, validation loss=3.33
# Epoch 17: 99.26s, train acc=0.83, train loss=3.13, validation acc=0.82, validation loss=3.27
# Epoch 18: 104.99s, train acc=0.83, train loss=3.09, validation acc=0.82, validation loss=3.25
# Epoch 19: 110.98s, train acc=0.83, train loss=3.05, validation acc=0.83, validation loss=3.20
# Epoch 20: 116.00s, train acc=0.84, train loss=2.99, validation acc=0.83, validation loss=3.14
#
# Test acc=0.83, Test loss=3.14
# Optimizer=sgd, Activation=leaky_relu, LR=0.01
# Epoch 1: 5.06s, train acc=0.68, train loss=5.83, validation acc=0.68, validation loss=5.85
# Epoch 2: 7.57s, train acc=0.76, train loss=4.50, validation acc=0.75, validation loss=4.55
# Epoch 3: 10.22s, train acc=0.79, train loss=3.89, validation acc=0.78, validation loss=4.00
# Epoch 4: 12.87s, train acc=0.81, train loss=3.54, validation acc=0.80, validation loss=3.67
# Epoch 5: 16.25s, train acc=0.82, train loss=3.32, validation acc=0.81, validation loss=3.46
# Epoch 6: 21.00s, train acc=0.83, train loss=3.12, validation acc=0.82, validation loss=3.27
# Epoch 7: 23.84s, train acc=0.84, train loss=2.99, validation acc=0.83, validation loss=3.16
# Epoch 8: 26.57s, train acc=0.84, train loss=2.87, validation acc=0.83, validation loss=3.10
# Epoch 9: 29.29s, train acc=0.85, train loss=2.80, validation acc=0.84, validation loss=3.03
# Epoch 10: 34.39s, train acc=0.85, train loss=2.71, validation acc=0.84, validation loss=2.91
# Epoch 11: 36.98s, train acc=0.86, train loss=2.64, validation acc=0.85, validation loss=2.85
# Epoch 12: 39.63s, train acc=0.86, train loss=2.56, validation acc=0.85, validation loss=2.78
# Epoch 13: 42.44s, train acc=0.86, train loss=2.51, validation acc=0.85, validation loss=2.70
# Epoch 14: 46.12s, train acc=0.87, train loss=2.46, validation acc=0.85, validation loss=2.67
# Epoch 15: 50.69s, train acc=0.87, train loss=2.41, validation acc=0.86, validation loss=2.63
# Epoch 16: 53.26s, train acc=0.87, train loss=2.39, validation acc=0.86, validation loss=2.65
# Epoch 17: 55.86s, train acc=0.87, train loss=2.35, validation acc=0.86, validation loss=2.60
# Epoch 18: 58.39s, train acc=0.87, train loss=2.32, validation acc=0.86, validation loss=2.58
# Epoch 19: 63.46s, train acc=0.88, train loss=2.25, validation acc=0.86, validation loss=2.49
# Epoch 20: 66.50s, train acc=0.88, train loss=2.24, validation acc=0.86, validation loss=2.53
#
# Test acc=0.86, Test loss=2.53
# Optimizer=sgd, Activation=leaky_relu, LR=0.001
# Epoch 1: 2.72s, train acc=0.33, train loss=12.35, validation acc=0.33, validation loss=12.42
# Epoch 2: 5.31s, train acc=0.44, train loss=10.41, validation acc=0.44, validation loss=10.35
# Epoch 3: 8.29s, train acc=0.50, train loss=9.13, validation acc=0.51, validation loss=9.02
# Epoch 4: 12.98s, train acc=0.55, train loss=8.27, validation acc=0.55, validation loss=8.23
# Epoch 5: 15.56s, train acc=0.58, train loss=7.65, validation acc=0.59, validation loss=7.60
# Epoch 6: 18.09s, train acc=0.61, train loss=7.17, validation acc=0.61, validation loss=7.17
# Epoch 7: 20.63s, train acc=0.63, train loss=6.79, validation acc=0.63, validation loss=6.81
# Epoch 8: 24.99s, train acc=0.65, train loss=6.49, validation acc=0.65, validation loss=6.50
# Epoch 9: 28.87s, train acc=0.66, train loss=6.22, validation acc=0.66, validation loss=6.23
# Epoch 10: 31.74s, train acc=0.67, train loss=5.99, validation acc=0.67, validation loss=6.03
# Epoch 11: 34.71s, train acc=0.69, train loss=5.79, validation acc=0.68, validation loss=5.88
# Epoch 12: 38.06s, train acc=0.70, train loss=5.60, validation acc=0.69, validation loss=5.70
# Epoch 13: 42.87s, train acc=0.70, train loss=5.46, validation acc=0.70, validation loss=5.53
# Epoch 14: 45.40s, train acc=0.71, train loss=5.31, validation acc=0.71, validation loss=5.40
# Epoch 15: 47.98s, train acc=0.72, train loss=5.19, validation acc=0.71, validation loss=5.30
# Epoch 16: 50.68s, train acc=0.72, train loss=5.08, validation acc=0.72, validation loss=5.18
# Epoch 17: 55.39s, train acc=0.73, train loss=4.96, validation acc=0.72, validation loss=5.10
# Epoch 18: 58.37s, train acc=0.74, train loss=4.87, validation acc=0.73, validation loss=5.01
# Epoch 19: 61.25s, train acc=0.74, train loss=4.79, validation acc=0.73, validation loss=4.94
# Epoch 20: 64.26s, train acc=0.74, train loss=4.70, validation acc=0.74, validation loss=4.85
#
# Test acc=0.74, Test loss=4.85
# Optimizer=sgd, Activation=selu, LR=0.01
# Epoch 1: 4.76s, train acc=0.83, train loss=3.07, validation acc=0.83, validation loss=3.12
# Epoch 2: 8.97s, train acc=0.86, train loss=2.55, validation acc=0.86, validation loss=2.57
# Epoch 3: 12.29s, train acc=0.87, train loss=2.33, validation acc=0.87, validation loss=2.41
# Epoch 4: 15.50s, train acc=0.88, train loss=2.21, validation acc=0.87, validation loss=2.32
# Epoch 5: 21.53s, train acc=0.88, train loss=2.12, validation acc=0.88, validation loss=2.22
# Epoch 6: 25.23s, train acc=0.89, train loss=1.99, validation acc=0.88, validation loss=2.13
# Epoch 7: 28.86s, train acc=0.90, train loss=1.89, validation acc=0.89, validation loss=2.10
# Epoch 8: 33.32s, train acc=0.90, train loss=1.91, validation acc=0.89, validation loss=2.10
# Epoch 9: 38.19s, train acc=0.89, train loss=1.96, validation acc=0.88, validation loss=2.18
# Epoch 10: 41.86s, train acc=0.90, train loss=1.80, validation acc=0.89, validation loss=2.02
# Epoch 11: 45.54s, train acc=0.90, train loss=1.86, validation acc=0.89, validation loss=2.11
# Epoch 12: 51.70s, train acc=0.90, train loss=1.82, validation acc=0.89, validation loss=2.03
# Epoch 13: 55.31s, train acc=0.91, train loss=1.68, validation acc=0.89, validation loss=1.97
# Epoch 14: 58.84s, train acc=0.90, train loss=1.75, validation acc=0.89, validation loss=2.01
# Epoch 15: 63.30s, train acc=0.91, train loss=1.62, validation acc=0.90, validation loss=1.91
# Epoch 16: 67.54s, train acc=0.90, train loss=1.81, validation acc=0.89, validation loss=2.10
# Epoch 17: 71.19s, train acc=0.91, train loss=1.70, validation acc=0.90, validation loss=1.93
# Epoch 18: 74.55s, train acc=0.91, train loss=1.68, validation acc=0.89, validation loss=2.00
# Epoch 19: 80.58s, train acc=0.92, train loss=1.50, validation acc=0.90, validation loss=1.87
# Epoch 20: 84.25s, train acc=0.91, train loss=1.57, validation acc=0.90, validation loss=1.90
#
# Test acc=0.90, Test loss=1.90
# Optimizer=sgd, Activation=selu, LR=0.001
# Epoch 1: 3.53s, train acc=0.60, train loss=7.34, validation acc=0.60, validation loss=7.36
# Epoch 2: 8.73s, train acc=0.71, train loss=5.31, validation acc=0.71, validation loss=5.34
# Epoch 3: 12.65s, train acc=0.76, train loss=4.44, validation acc=0.76, validation loss=4.51
# Epoch 4: 16.16s, train acc=0.78, train loss=4.00, validation acc=0.78, validation loss=4.07
# Epoch 5: 20.00s, train acc=0.80, train loss=3.72, validation acc=0.80, validation loss=3.76
# Epoch 6: 25.70s, train acc=0.81, train loss=3.46, validation acc=0.81, validation loss=3.52
# Epoch 7: 29.22s, train acc=0.82, train loss=3.31, validation acc=0.82, validation loss=3.34
# Epoch 8: 32.48s, train acc=0.83, train loss=3.18, validation acc=0.83, validation loss=3.19
# Epoch 9: 37.34s, train acc=0.83, train loss=3.05, validation acc=0.83, validation loss=3.10
# Epoch 10: 41.42s, train acc=0.84, train loss=2.96, validation acc=0.84, validation loss=2.98
# Epoch 11: 45.00s, train acc=0.84, train loss=2.91, validation acc=0.84, validation loss=2.95
# Epoch 12: 48.65s, train acc=0.85, train loss=2.84, validation acc=0.84, validation loss=2.88
# Epoch 13: 54.58s, train acc=0.85, train loss=2.79, validation acc=0.85, validation loss=2.85
# Epoch 14: 58.24s, train acc=0.85, train loss=2.73, validation acc=0.85, validation loss=2.79
# Epoch 15: 61.81s, train acc=0.85, train loss=2.69, validation acc=0.85, validation loss=2.76
# Epoch 16: 67.02s, train acc=0.86, train loss=2.65, validation acc=0.85, validation loss=2.76
# Epoch 17: 70.97s, train acc=0.86, train loss=2.61, validation acc=0.85, validation loss=2.71
# Epoch 18: 74.53s, train acc=0.86, train loss=2.57, validation acc=0.85, validation loss=2.67
# Epoch 19: 78.08s, train acc=0.86, train loss=2.55, validation acc=0.86, validation loss=2.64
# Epoch 20: 83.74s, train acc=0.86, train loss=2.52, validation acc=0.86, validation loss=2.62
#
# Test acc=0.86, Test loss=2.62
# Optimizer=sgd, Activation=elu, LR=0.01
# Epoch 1: 3.49s, train acc=0.81, train loss=3.52, validation acc=0.80, validation loss=3.60
# Epoch 2: 6.76s, train acc=0.84, train loss=2.90, validation acc=0.84, validation loss=2.99
# Epoch 3: 11.23s, train acc=0.86, train loss=2.62, validation acc=0.85, validation loss=2.78
# Epoch 4: 15.99s, train acc=0.87, train loss=2.46, validation acc=0.86, validation loss=2.62
# Epoch 5: 19.63s, train acc=0.87, train loss=2.36, validation acc=0.86, validation loss=2.55
# Epoch 6: 23.31s, train acc=0.88, train loss=2.28, validation acc=0.87, validation loss=2.47
# Epoch 7: 29.38s, train acc=0.88, train loss=2.19, validation acc=0.87, validation loss=2.34
# Epoch 8: 32.95s, train acc=0.88, train loss=2.17, validation acc=0.87, validation loss=2.33
# Epoch 9: 36.61s, train acc=0.89, train loss=2.09, validation acc=0.88, validation loss=2.29
# Epoch 10: 42.74s, train acc=0.89, train loss=2.08, validation acc=0.88, validation loss=2.26
# Epoch 11: 46.53s, train acc=0.89, train loss=2.00, validation acc=0.88, validation loss=2.20
# Epoch 12: 50.05s, train acc=0.89, train loss=1.99, validation acc=0.88, validation loss=2.23
# Epoch 13: 54.06s, train acc=0.90, train loss=1.92, validation acc=0.88, validation loss=2.12
# Epoch 14: 59.51s, train acc=0.90, train loss=1.90, validation acc=0.88, validation loss=2.16
# Epoch 15: 63.06s, train acc=0.90, train loss=1.89, validation acc=0.89, validation loss=2.08
# Epoch 16: 66.69s, train acc=0.90, train loss=1.87, validation acc=0.89, validation loss=2.11
# Epoch 17: 72.55s, train acc=0.90, train loss=1.81, validation acc=0.89, validation loss=2.06
# Epoch 18: 76.18s, train acc=0.90, train loss=1.79, validation acc=0.89, validation loss=2.04
# Epoch 19: 79.69s, train acc=0.91, train loss=1.74, validation acc=0.89, validation loss=2.01
# Epoch 20: 83.71s, train acc=0.91, train loss=1.75, validation acc=0.89, validation loss=1.98
#
# Test acc=0.89, Test loss=1.98
# Optimizer=sgd, Activation=elu, LR=0.001
# Epoch 1: 5.50s, train acc=0.52, train loss=8.87, validation acc=0.52, validation loss=8.90
# Epoch 2: 9.14s, train acc=0.64, train loss=6.66, validation acc=0.64, validation loss=6.65
# Epoch 3: 12.80s, train acc=0.69, train loss=5.64, validation acc=0.70, validation loss=5.54
# Epoch 4: 19.02s, train acc=0.73, train loss=5.03, validation acc=0.73, validation loss=4.94
# Epoch 5: 22.86s, train acc=0.75, train loss=4.61, validation acc=0.75, validation loss=4.54
# Epoch 6: 26.60s, train acc=0.77, train loss=4.31, validation acc=0.77, validation loss=4.25
# Epoch 7: 32.58s, train acc=0.78, train loss=4.08, validation acc=0.78, validation loss=4.02
# Epoch 8: 35.87s, train acc=0.79, train loss=3.89, validation acc=0.79, validation loss=3.88
# Epoch 9: 39.55s, train acc=0.80, train loss=3.73, validation acc=0.80, validation loss=3.77
# Epoch 10: 43.84s, train acc=0.80, train loss=3.61, validation acc=0.80, validation loss=3.64
# Epoch 11: 49.44s, train acc=0.81, train loss=3.48, validation acc=0.81, validation loss=3.55
# Epoch 12: 53.37s, train acc=0.82, train loss=3.40, validation acc=0.81, validation loss=3.46
# Epoch 13: 57.17s, train acc=0.82, train loss=3.34, validation acc=0.81, validation loss=3.42
# Epoch 14: 63.55s, train acc=0.82, train loss=3.25, validation acc=0.82, validation loss=3.35
# Epoch 15: 67.45s, train acc=0.83, train loss=3.18, validation acc=0.82, validation loss=3.27
# Epoch 16: 74.27s, train acc=0.83, train loss=3.14, validation acc=0.83, validation loss=3.22
# Epoch 17: 79.65s, train acc=0.83, train loss=3.08, validation acc=0.83, validation loss=3.17
# Epoch 18: 83.22s, train acc=0.84, train loss=3.02, validation acc=0.83, validation loss=3.11
# Epoch 19: 86.92s, train acc=0.84, train loss=2.98, validation acc=0.83, validation loss=3.05
# Epoch 20: 93.09s, train acc=0.84, train loss=2.94, validation acc=0.84, validation loss=3.03
#
# Test acc=0.84, Test loss=3.03
# Optimizer=momentum, Activation=relu, LR=0.01
# Epoch 1: 2.98s, train acc=0.72, train loss=5.10, validation acc=0.72, validation loss=5.14
# Epoch 2: 6.00s, train acc=0.78, train loss=4.01, validation acc=0.77, validation loss=4.15
# Epoch 3: 9.23s, train acc=0.81, train loss=3.50, validation acc=0.80, validation loss=3.72
# Epoch 4: 14.78s, train acc=0.83, train loss=3.21, validation acc=0.81, validation loss=3.45
# Epoch 5: 17.97s, train acc=0.84, train loss=2.98, validation acc=0.82, validation loss=3.24
# Epoch 6: 20.99s, train acc=0.85, train loss=2.81, validation acc=0.83, validation loss=3.09
# Epoch 7: 24.25s, train acc=0.85, train loss=2.69, validation acc=0.84, validation loss=2.98
# Epoch 8: 29.50s, train acc=0.86, train loss=2.59, validation acc=0.84, validation loss=2.88
# Epoch 9: 32.52s, train acc=0.87, train loss=2.48, validation acc=0.85, validation loss=2.78
# Epoch 10: 35.45s, train acc=0.87, train loss=2.40, validation acc=0.85, validation loss=2.71
# Epoch 11: 38.48s, train acc=0.87, train loss=2.34, validation acc=0.86, validation loss=2.63
# Epoch 12: 43.98s, train acc=0.88, train loss=2.28, validation acc=0.86, validation loss=2.57
# Epoch 13: 47.03s, train acc=0.88, train loss=2.22, validation acc=0.86, validation loss=2.53
# Epoch 14: 50.36s, train acc=0.88, train loss=2.18, validation acc=0.86, validation loss=2.49
# Epoch 15: 53.86s, train acc=0.89, train loss=2.11, validation acc=0.87, validation loss=2.45
# Epoch 16: 58.98s, train acc=0.89, train loss=2.09, validation acc=0.87, validation loss=2.43
# Epoch 17: 62.17s, train acc=0.89, train loss=2.06, validation acc=0.87, validation loss=2.40
# Epoch 18: 65.50s, train acc=0.89, train loss=2.04, validation acc=0.87, validation loss=2.37
# Epoch 19: 69.51s, train acc=0.89, train loss=2.02, validation acc=0.87, validation loss=2.32
# Epoch 20: 74.19s, train acc=0.89, train loss=1.97, validation acc=0.87, validation loss=2.33
#
# Test acc=0.87, Test loss=2.33
# Optimizer=momentum, Activation=relu, LR=0.001
# Epoch 1: 3.13s, train acc=0.33, train loss=12.35, validation acc=0.33, validation loss=12.34
# Epoch 2: 6.12s, train acc=0.44, train loss=10.29, validation acc=0.45, validation loss=10.19
# Epoch 3: 9.93s, train acc=0.50, train loss=9.12, validation acc=0.51, validation loss=8.99
# Epoch 4: 14.53s, train acc=0.55, train loss=8.26, validation acc=0.55, validation loss=8.22
# Epoch 5: 17.63s, train acc=0.58, train loss=7.67, validation acc=0.58, validation loss=7.68
# Epoch 6: 20.71s, train acc=0.61, train loss=7.23, validation acc=0.61, validation loss=7.21
# Epoch 7: 24.92s, train acc=0.63, train loss=6.86, validation acc=0.63, validation loss=6.82
# Epoch 8: 29.32s, train acc=0.65, train loss=6.54, validation acc=0.64, validation loss=6.55
# Epoch 9: 32.45s, train acc=0.66, train loss=6.27, validation acc=0.66, validation loss=6.29
# Epoch 10: 35.74s, train acc=0.67, train loss=6.04, validation acc=0.67, validation loss=6.08
# Epoch 11: 40.36s, train acc=0.68, train loss=5.83, validation acc=0.68, validation loss=5.91
# Epoch 12: 43.95s, train acc=0.69, train loss=5.65, validation acc=0.69, validation loss=5.77
# Epoch 13: 47.09s, train acc=0.70, train loss=5.50, validation acc=0.70, validation loss=5.60
# Epoch 14: 50.08s, train acc=0.71, train loss=5.36, validation acc=0.70, validation loss=5.45
# Epoch 15: 53.95s, train acc=0.72, train loss=5.24, validation acc=0.71, validation loss=5.31
# Epoch 16: 58.32s, train acc=0.72, train loss=5.14, validation acc=0.72, validation loss=5.21
# Epoch 17: 61.09s, train acc=0.73, train loss=5.02, validation acc=0.72, validation loss=5.09
# Epoch 18: 64.09s, train acc=0.73, train loss=4.92, validation acc=0.73, validation loss=5.00
# Epoch 19: 68.22s, train acc=0.74, train loss=4.83, validation acc=0.73, validation loss=4.90
# Epoch 20: 73.08s, train acc=0.74, train loss=4.73, validation acc=0.74, validation loss=4.82
#
# Test acc=0.74, Test loss=4.82
# Optimizer=momentum, Activation=sigmoid, LR=0.01
# Epoch 1: 3.66s, train acc=0.43, train loss=10.41, validation acc=0.44, validation loss=10.30
# Epoch 2: 7.58s, train acc=0.57, train loss=8.01, validation acc=0.57, validation loss=7.92
# Epoch 3: 14.01s, train acc=0.63, train loss=6.85, validation acc=0.63, validation loss=6.81
# Epoch 4: 17.86s, train acc=0.69, train loss=5.80, validation acc=0.69, validation loss=5.79
# Epoch 5: 21.43s, train acc=0.70, train loss=5.46, validation acc=0.71, validation loss=5.42
# Epoch 6: 28.29s, train acc=0.72, train loss=5.07, validation acc=0.73, validation loss=4.92
# Epoch 7: 32.16s, train acc=0.71, train loss=5.42, validation acc=0.72, validation loss=5.24
# Epoch 8: 35.74s, train acc=0.75, train loss=4.63, validation acc=0.75, validation loss=4.52
# Epoch 9: 40.44s, train acc=0.78, train loss=4.08, validation acc=0.78, validation loss=4.00
# Epoch 10: 45.29s, train acc=0.78, train loss=3.99, validation acc=0.79, validation loss=3.90
# Epoch 11: 49.03s, train acc=0.79, train loss=3.86, validation acc=0.79, validation loss=3.81
# Epoch 12: 52.79s, train acc=0.79, train loss=3.78, validation acc=0.80, validation loss=3.71
# Epoch 13: 59.02s, train acc=0.80, train loss=3.77, validation acc=0.80, validation loss=3.73
# Epoch 14: 62.42s, train acc=0.81, train loss=3.46, validation acc=0.82, validation loss=3.39
# Epoch 15: 66.15s, train acc=0.81, train loss=3.47, validation acc=0.82, validation loss=3.39
# Epoch 16: 72.29s, train acc=0.81, train loss=3.45, validation acc=0.82, validation loss=3.41
# Epoch 17: 75.82s, train acc=0.82, train loss=3.31, validation acc=0.82, validation loss=3.29
# Epoch 18: 79.49s, train acc=0.81, train loss=3.44, validation acc=0.82, validation loss=3.37
# Epoch 19: 84.65s, train acc=0.82, train loss=3.41, validation acc=0.82, validation loss=3.32
# Epoch 20: 89.81s, train acc=0.80, train loss=3.69, validation acc=0.80, validation loss=3.69
#
# Test acc=0.80, Test loss=3.69
# Optimizer=momentum, Activation=sigmoid, LR=0.001
# Epoch 1: 3.81s, train acc=0.15, train loss=15.64, validation acc=0.15, validation loss=15.64
# Epoch 2: 7.85s, train acc=0.19, train loss=14.93, validation acc=0.19, validation loss=14.97
# Epoch 3: 13.81s, train acc=0.21, train loss=14.58, validation acc=0.21, validation loss=14.62
# Epoch 4: 17.73s, train acc=0.24, train loss=14.02, validation acc=0.24, validation loss=14.07
# Epoch 5: 21.62s, train acc=0.26, train loss=13.55, validation acc=0.26, validation loss=13.61
# Epoch 6: 27.81s, train acc=0.29, train loss=13.13, validation acc=0.29, validation loss=13.13
# Epoch 7: 31.47s, train acc=0.31, train loss=12.79, validation acc=0.31, validation loss=12.78
# Epoch 8: 35.43s, train acc=0.33, train loss=12.27, validation acc=0.34, validation loss=12.25
# Epoch 9: 41.80s, train acc=0.36, train loss=11.76, validation acc=0.37, validation loss=11.69
# Epoch 10: 45.46s, train acc=0.38, train loss=11.35, validation acc=0.39, validation loss=11.24
# Epoch 11: 49.39s, train acc=0.40, train loss=10.97, validation acc=0.41, validation loss=10.84
# Epoch 12: 54.75s, train acc=0.43, train loss=10.53, validation acc=0.43, validation loss=10.43
# Epoch 13: 59.30s, train acc=0.44, train loss=10.27, validation acc=0.45, validation loss=10.11
# Epoch 14: 62.87s, train acc=0.46, train loss=9.94, validation acc=0.47, validation loss=9.77
# Epoch 15: 66.98s, train acc=0.48, train loss=9.66, validation acc=0.48, validation loss=9.53
# Epoch 16: 72.60s, train acc=0.50, train loss=9.24, validation acc=0.51, validation loss=9.10
# Epoch 17: 76.37s, train acc=0.51, train loss=9.03, validation acc=0.52, validation loss=8.89
# Epoch 18: 80.11s, train acc=0.52, train loss=8.81, validation acc=0.53, validation loss=8.71
# Epoch 19: 86.61s, train acc=0.53, train loss=8.57, validation acc=0.54, validation loss=8.46
# Epoch 20: 90.49s, train acc=0.55, train loss=8.32, validation acc=0.55, validation loss=8.20
#
# Test acc=0.55, Test loss=8.20
# Optimizer=momentum, Activation=tanh, LR=0.01
# Epoch 1: 5.80s, train acc=0.81, train loss=3.49, validation acc=0.81, validation loss=3.51
# Epoch 2: 13.23s, train acc=0.84, train loss=2.86, validation acc=0.84, validation loss=2.97
# Epoch 3: 18.71s, train acc=0.86, train loss=2.55, validation acc=0.86, validation loss=2.67
# Epoch 4: 26.74s, train acc=0.87, train loss=2.41, validation acc=0.86, validation loss=2.54
# Epoch 5: 32.36s, train acc=0.87, train loss=2.35, validation acc=0.87, validation loss=2.47
# Epoch 6: 40.20s, train acc=0.88, train loss=2.25, validation acc=0.87, validation loss=2.39
# Epoch 7: 45.72s, train acc=0.88, train loss=2.17, validation acc=0.88, validation loss=2.28
# Epoch 8: 52.91s, train acc=0.88, train loss=2.13, validation acc=0.88, validation loss=2.28
# Epoch 9: 58.75s, train acc=0.89, train loss=2.10, validation acc=0.88, validation loss=2.24
# Epoch 10: 64.35s, train acc=0.89, train loss=2.02, validation acc=0.88, validation loss=2.20
# Epoch 11: 71.97s, train acc=0.89, train loss=2.00, validation acc=0.88, validation loss=2.12
# Epoch 12: 77.53s, train acc=0.89, train loss=1.94, validation acc=0.88, validation loss=2.12
# Epoch 13: 85.52s, train acc=0.89, train loss=2.00, validation acc=0.88, validation loss=2.15
# Epoch 14: 91.01s, train acc=0.90, train loss=1.91, validation acc=0.89, validation loss=2.05
# Epoch 15: 98.76s, train acc=0.90, train loss=1.86, validation acc=0.89, validation loss=2.01
# Epoch 16: 104.44s, train acc=0.90, train loss=1.86, validation acc=0.89, validation loss=2.02
# Epoch 17: 111.74s, train acc=0.90, train loss=1.88, validation acc=0.89, validation loss=2.09
# Epoch 18: 117.26s, train acc=0.90, train loss=1.79, validation acc=0.89, validation loss=2.01
# Epoch 19: 123.33s, train acc=0.90, train loss=1.78, validation acc=0.89, validation loss=2.00
# Epoch 20: 130.51s, train acc=0.90, train loss=1.80, validation acc=0.89, validation loss=1.98
#
# Test acc=0.89, Test loss=1.98
# Optimizer=momentum, Activation=tanh, LR=0.001
# Epoch 1: 5.51s, train acc=0.50, train loss=9.16, validation acc=0.50, validation loss=9.15
# Epoch 2: 13.85s, train acc=0.64, train loss=6.64, validation acc=0.64, validation loss=6.60
# Epoch 3: 19.40s, train acc=0.70, train loss=5.53, validation acc=0.70, validation loss=5.60
# Epoch 4: 27.40s, train acc=0.73, train loss=4.92, validation acc=0.73, validation loss=5.00
# Epoch 5: 32.85s, train acc=0.76, train loss=4.51, validation acc=0.75, validation loss=4.53
# Epoch 6: 40.43s, train acc=0.77, train loss=4.22, validation acc=0.77, validation loss=4.24
# Epoch 7: 46.17s, train acc=0.78, train loss=4.00, validation acc=0.78, validation loss=4.03
# Epoch 8: 52.44s, train acc=0.79, train loss=3.80, validation acc=0.79, validation loss=3.88
# Epoch 9: 59.21s, train acc=0.80, train loss=3.68, validation acc=0.80, validation loss=3.72
# Epoch 10: 65.12s, train acc=0.81, train loss=3.56, validation acc=0.80, validation loss=3.61
# Epoch 11: 72.40s, train acc=0.81, train loss=3.45, validation acc=0.81, validation loss=3.50
# Epoch 12: 78.13s, train acc=0.82, train loss=3.35, validation acc=0.81, validation loss=3.41
# Epoch 13: 85.99s, train acc=0.82, train loss=3.26, validation acc=0.82, validation loss=3.33
# Epoch 14: 91.49s, train acc=0.83, train loss=3.20, validation acc=0.82, validation loss=3.26
# Epoch 15: 99.47s, train acc=0.83, train loss=3.14, validation acc=0.83, validation loss=3.22
# Epoch 16: 105.22s, train acc=0.83, train loss=3.10, validation acc=0.83, validation loss=3.19
# Epoch 17: 112.96s, train acc=0.84, train loss=3.04, validation acc=0.83, validation loss=3.11
# Epoch 18: 118.72s, train acc=0.84, train loss=2.98, validation acc=0.83, validation loss=3.05
# Epoch 19: 125.56s, train acc=0.84, train loss=2.94, validation acc=0.84, validation loss=3.01
# Epoch 20: 131.77s, train acc=0.84, train loss=2.92, validation acc=0.84, validation loss=2.97
#
# Test acc=0.84, Test loss=2.97
# Optimizer=momentum, Activation=leaky_relu, LR=0.01
# Epoch 1: 3.43s, train acc=0.71, train loss=5.35, validation acc=0.71, validation loss=5.35
# Epoch 2: 8.63s, train acc=0.77, train loss=4.31, validation acc=0.77, validation loss=4.31
# Epoch 3: 12.46s, train acc=0.79, train loss=3.89, validation acc=0.79, validation loss=3.93
# Epoch 4: 15.81s, train acc=0.80, train loss=3.60, validation acc=0.81, validation loss=3.59
# Epoch 5: 19.08s, train acc=0.82, train loss=3.39, validation acc=0.82, validation loss=3.40
# Epoch 6: 25.05s, train acc=0.82, train loss=3.27, validation acc=0.82, validation loss=3.31
# Epoch 7: 28.48s, train acc=0.83, train loss=3.13, validation acc=0.83, validation loss=3.21
# Epoch 8: 31.90s, train acc=0.83, train loss=3.05, validation acc=0.83, validation loss=3.16
# Epoch 9: 35.71s, train acc=0.84, train loss=2.98, validation acc=0.83, validation loss=3.11
# Epoch 10: 40.87s, train acc=0.84, train loss=2.95, validation acc=0.83, validation loss=3.05
# Epoch 11: 44.30s, train acc=0.84, train loss=2.88, validation acc=0.84, validation loss=3.04
# Epoch 12: 47.70s, train acc=0.85, train loss=2.84, validation acc=0.84, validation loss=2.98
# Epoch 13: 52.67s, train acc=0.85, train loss=2.80, validation acc=0.84, validation loss=2.97
# Epoch 14: 56.73s, train acc=0.85, train loss=2.79, validation acc=0.84, validation loss=2.93
# Epoch 15: 60.17s, train acc=0.85, train loss=2.76, validation acc=0.84, validation loss=2.93
# Epoch 16: 63.63s, train acc=0.85, train loss=2.71, validation acc=0.84, validation loss=2.90
# Epoch 17: 69.47s, train acc=0.85, train loss=2.68, validation acc=0.84, validation loss=2.87
# Epoch 18: 72.86s, train acc=0.85, train loss=2.68, validation acc=0.84, validation loss=2.90
# Epoch 19: 76.17s, train acc=0.85, train loss=2.67, validation acc=0.84, validation loss=2.87
# Epoch 20: 80.04s, train acc=0.86, train loss=2.63, validation acc=0.85, validation loss=2.81
#
# Test acc=0.85, Test loss=2.81
# Optimizer=momentum, Activation=leaky_relu, LR=0.001
# Epoch 1: 5.02s, train acc=0.23, train loss=14.12, validation acc=0.23, validation loss=14.13
# Epoch 2: 8.24s, train acc=0.37, train loss=11.58, validation acc=0.36, validation loss=11.75
# Epoch 3: 11.59s, train acc=0.45, train loss=10.14, validation acc=0.45, validation loss=10.20
# Epoch 4: 16.77s, train acc=0.50, train loss=9.16, validation acc=0.50, validation loss=9.22
# Epoch 5: 20.65s, train acc=0.54, train loss=8.47, validation acc=0.54, validation loss=8.54
# Epoch 6: 24.00s, train acc=0.57, train loss=7.94, validation acc=0.56, validation loss=8.04
# Epoch 7: 27.33s, train acc=0.59, train loss=7.52, validation acc=0.59, validation loss=7.57
# Epoch 8: 33.02s, train acc=0.61, train loss=7.16, validation acc=0.61, validation loss=7.27
# Epoch 9: 36.27s, train acc=0.63, train loss=6.89, validation acc=0.62, validation loss=6.99
# Epoch 10: 39.50s, train acc=0.64, train loss=6.64, validation acc=0.63, validation loss=6.76
# Epoch 11: 43.06s, train acc=0.65, train loss=6.39, validation acc=0.64, validation loss=6.54
# Epoch 12: 48.57s, train acc=0.66, train loss=6.18, validation acc=0.66, validation loss=6.35
# Epoch 13: 51.58s, train acc=0.67, train loss=6.01, validation acc=0.67, validation loss=6.17
# Epoch 14: 55.00s, train acc=0.68, train loss=5.87, validation acc=0.67, validation loss=6.00
# Epoch 15: 58.87s, train acc=0.69, train loss=5.71, validation acc=0.68, validation loss=5.84
# Epoch 16: 63.84s, train acc=0.70, train loss=5.59, validation acc=0.69, validation loss=5.70
# Epoch 17: 67.40s, train acc=0.70, train loss=5.47, validation acc=0.70, validation loss=5.56
# Epoch 18: 70.79s, train acc=0.71, train loss=5.36, validation acc=0.70, validation loss=5.44
# Epoch 19: 76.48s, train acc=0.71, train loss=5.25, validation acc=0.71, validation loss=5.36
# Epoch 20: 79.79s, train acc=0.72, train loss=5.16, validation acc=0.71, validation loss=5.29
#
# Test acc=0.71, Test loss=5.29
# Optimizer=momentum, Activation=selu, LR=0.01
# Epoch 1: 4.06s, train acc=0.84, train loss=2.90, validation acc=0.84, validation loss=2.89
# Epoch 2: 9.07s, train acc=0.87, train loss=2.45, validation acc=0.87, validation loss=2.46
# Epoch 3: 14.32s, train acc=0.88, train loss=2.26, validation acc=0.87, validation loss=2.32
# Epoch 4: 18.26s, train acc=0.89, train loss=2.09, validation acc=0.88, validation loss=2.21
# Epoch 5: 23.91s, train acc=0.89, train loss=2.01, validation acc=0.88, validation loss=2.16
# Epoch 6: 29.34s, train acc=0.89, train loss=2.04, validation acc=0.88, validation loss=2.13
# Epoch 7: 33.43s, train acc=0.90, train loss=1.85, validation acc=0.89, validation loss=2.03
# Epoch 8: 37.96s, train acc=0.90, train loss=1.82, validation acc=0.89, validation loss=2.04
# Epoch 9: 43.80s, train acc=0.90, train loss=1.88, validation acc=0.89, validation loss=2.09
# Epoch 10: 47.89s, train acc=0.91, train loss=1.68, validation acc=0.89, validation loss=1.94
# Epoch 11: 52.21s, train acc=0.91, train loss=1.65, validation acc=0.90, validation loss=1.93
# Epoch 12: 58.19s, train acc=0.91, train loss=1.64, validation acc=0.90, validation loss=1.91
# Epoch 13: 62.10s, train acc=0.91, train loss=1.62, validation acc=0.90, validation loss=1.90
# Epoch 14: 66.20s, train acc=0.91, train loss=1.62, validation acc=0.90, validation loss=1.88
# Epoch 15: 72.66s, train acc=0.91, train loss=1.59, validation acc=0.90, validation loss=1.86
# Epoch 16: 76.79s, train acc=0.92, train loss=1.45, validation acc=0.91, validation loss=1.72
# Epoch 17: 80.94s, train acc=0.92, train loss=1.45, validation acc=0.91, validation loss=1.75
# Epoch 18: 87.41s, train acc=0.92, train loss=1.39, validation acc=0.91, validation loss=1.71
# Epoch 19: 91.31s, train acc=0.92, train loss=1.44, validation acc=0.91, validation loss=1.73
# Epoch 20: 95.39s, train acc=0.92, train loss=1.41, validation acc=0.91, validation loss=1.73
#
# Test acc=0.91, Test loss=1.73
# Optimizer=momentum, Activation=selu, LR=0.001
# Epoch 1: 6.46s, train acc=0.62, train loss=7.06, validation acc=0.61, validation loss=7.20
# Epoch 2: 10.61s, train acc=0.72, train loss=5.18, validation acc=0.71, validation loss=5.33
# Epoch 3: 14.59s, train acc=0.76, train loss=4.40, validation acc=0.76, validation loss=4.51
# Epoch 4: 20.93s, train acc=0.79, train loss=3.95, validation acc=0.78, validation loss=4.10
# Epoch 5: 24.84s, train acc=0.80, train loss=3.65, validation acc=0.79, validation loss=3.80
# Epoch 6: 28.76s, train acc=0.81, train loss=3.47, validation acc=0.81, validation loss=3.59
# Epoch 7: 35.44s, train acc=0.82, train loss=3.29, validation acc=0.82, validation loss=3.39
# Epoch 8: 39.54s, train acc=0.83, train loss=3.17, validation acc=0.82, validation loss=3.25
# Epoch 9: 43.36s, train acc=0.83, train loss=3.08, validation acc=0.83, validation loss=3.15
# Epoch 10: 49.83s, train acc=0.84, train loss=2.99, validation acc=0.83, validation loss=3.07
# Epoch 11: 53.90s, train acc=0.84, train loss=2.92, validation acc=0.84, validation loss=2.99
# Epoch 12: 58.03s, train acc=0.85, train loss=2.84, validation acc=0.84, validation loss=2.91
# Epoch 13: 64.64s, train acc=0.85, train loss=2.78, validation acc=0.85, validation loss=2.84
# Epoch 14: 68.59s, train acc=0.85, train loss=2.74, validation acc=0.85, validation loss=2.80
# Epoch 15: 72.70s, train acc=0.85, train loss=2.69, validation acc=0.85, validation loss=2.76
# Epoch 16: 79.31s, train acc=0.86, train loss=2.64, validation acc=0.85, validation loss=2.72
# Epoch 17: 83.45s, train acc=0.86, train loss=2.60, validation acc=0.85, validation loss=2.69
# Epoch 18: 87.50s, train acc=0.86, train loss=2.57, validation acc=0.86, validation loss=2.67
# Epoch 19: 93.90s, train acc=0.86, train loss=2.53, validation acc=0.86, validation loss=2.64
# Epoch 20: 97.84s, train acc=0.86, train loss=2.52, validation acc=0.86, validation loss=2.59
#
# Test acc=0.86, Test loss=2.59
# Optimizer=momentum, Activation=elu, LR=0.01
# Epoch 1: 3.88s, train acc=0.80, train loss=3.65, validation acc=0.81, validation loss=3.59
# Epoch 2: 10.08s, train acc=0.84, train loss=2.97, validation acc=0.84, validation loss=2.89
# Epoch 3: 13.69s, train acc=0.85, train loss=2.70, validation acc=0.85, validation loss=2.71
# Epoch 4: 17.57s, train acc=0.87, train loss=2.48, validation acc=0.86, validation loss=2.56
# Epoch 5: 22.62s, train acc=0.87, train loss=2.39, validation acc=0.86, validation loss=2.49
# Epoch 6: 26.85s, train acc=0.88, train loss=2.28, validation acc=0.87, validation loss=2.37
# Epoch 7: 30.77s, train acc=0.88, train loss=2.22, validation acc=0.88, validation loss=2.29
# Epoch 8: 35.94s, train acc=0.88, train loss=2.14, validation acc=0.88, validation loss=2.26
# Epoch 9: 40.82s, train acc=0.89, train loss=2.10, validation acc=0.88, validation loss=2.23
# Epoch 10: 44.57s, train acc=0.89, train loss=2.07, validation acc=0.88, validation loss=2.23
# Epoch 11: 49.07s, train acc=0.89, train loss=2.00, validation acc=0.88, validation loss=2.17
# Epoch 12: 54.64s, train acc=0.89, train loss=1.97, validation acc=0.88, validation loss=2.15
# Epoch 13: 58.29s, train acc=0.90, train loss=1.92, validation acc=0.89, validation loss=2.07
# Epoch 14: 62.21s, train acc=0.90, train loss=1.92, validation acc=0.89, validation loss=2.10
# Epoch 15: 68.48s, train acc=0.90, train loss=1.84, validation acc=0.89, validation loss=2.03
# Epoch 16: 72.39s, train acc=0.90, train loss=1.83, validation acc=0.89, validation loss=2.02
# Epoch 17: 76.30s, train acc=0.90, train loss=1.83, validation acc=0.89, validation loss=2.01
# Epoch 18: 82.75s, train acc=0.91, train loss=1.75, validation acc=0.89, validation loss=2.00
# Epoch 19: 86.66s, train acc=0.90, train loss=1.80, validation acc=0.89, validation loss=1.96
# Epoch 20: 90.49s, train acc=0.90, train loss=1.76, validation acc=0.90, validation loss=1.93
#
# Test acc=0.90, Test loss=1.93
# Optimizer=momentum, Activation=elu, LR=0.001
# Epoch 1: 6.35s, train acc=0.47, train loss=9.84, validation acc=0.47, validation loss=9.81
# Epoch 2: 10.42s, train acc=0.62, train loss=7.03, validation acc=0.62, validation loss=7.05
# Epoch 3: 14.34s, train acc=0.68, train loss=5.81, validation acc=0.68, validation loss=5.83
# Epoch 4: 20.63s, train acc=0.72, train loss=5.11, validation acc=0.72, validation loss=5.09
# Epoch 5: 24.53s, train acc=0.75, train loss=4.65, validation acc=0.75, validation loss=4.66
# Epoch 6: 28.46s, train acc=0.77, train loss=4.31, validation acc=0.76, validation loss=4.36
# Epoch 7: 34.01s, train acc=0.78, train loss=4.08, validation acc=0.78, validation loss=4.09
# Epoch 8: 38.42s, train acc=0.79, train loss=3.89, validation acc=0.79, validation loss=3.93
# Epoch 9: 42.17s, train acc=0.80, train loss=3.73, validation acc=0.80, validation loss=3.75
# Epoch 10: 46.86s, train acc=0.80, train loss=3.59, validation acc=0.80, validation loss=3.62
# Epoch 11: 52.13s, train acc=0.81, train loss=3.49, validation acc=0.81, validation loss=3.49
# Epoch 12: 56.16s, train acc=0.82, train loss=3.38, validation acc=0.82, validation loss=3.40
# Epoch 13: 60.50s, train acc=0.82, train loss=3.30, validation acc=0.82, validation loss=3.33
# Epoch 14: 66.27s, train acc=0.82, train loss=3.23, validation acc=0.82, validation loss=3.27
# Epoch 15: 70.36s, train acc=0.83, train loss=3.16, validation acc=0.83, validation loss=3.21
# Epoch 16: 74.40s, train acc=0.83, train loss=3.11, validation acc=0.83, validation loss=3.16
# Epoch 17: 80.51s, train acc=0.83, train loss=3.06, validation acc=0.83, validation loss=3.10
# Epoch 18: 84.55s, train acc=0.84, train loss=3.00, validation acc=0.83, validation loss=3.07
# Epoch 19: 88.63s, train acc=0.84, train loss=2.96, validation acc=0.84, validation loss=3.02
# Epoch 20: 94.94s, train acc=0.84, train loss=2.92, validation acc=0.84, validation loss=2.97
#
# Test acc=0.84, Test loss=2.97
# Optimizer=adam, Activation=relu, LR=0.01
# Epoch 1: 3.80s, train acc=0.21, train loss=14.52, validation acc=0.21, validation loss=14.46
# Epoch 2: 7.58s, train acc=0.21, train loss=14.61, validation acc=0.21, validation loss=14.47
# Epoch 3: 13.51s, train acc=0.21, train loss=14.53, validation acc=0.22, validation loss=14.44
# Epoch 4: 17.11s, train acc=0.21, train loss=14.59, validation acc=0.21, validation loss=14.61
# Epoch 5: 20.86s, train acc=0.22, train loss=14.29, validation acc=0.23, validation loss=14.26
# Epoch 6: 26.67s, train acc=0.23, train loss=14.18, validation acc=0.23, validation loss=14.15
# Epoch 7: 30.80s, train acc=0.23, train loss=14.26, validation acc=0.23, validation loss=14.26
# Epoch 8: 34.55s, train acc=0.20, train loss=14.76, validation acc=0.21, validation loss=14.64
# Epoch 9: 39.23s, train acc=0.24, train loss=13.97, validation acc=0.24, validation loss=13.94
# Epoch 10: 44.40s, train acc=0.23, train loss=14.12, validation acc=0.24, validation loss=14.08
# Epoch 11: 48.26s, train acc=0.24, train loss=13.99, validation acc=0.24, validation loss=14.06
# Epoch 12: 52.02s, train acc=0.24, train loss=14.00, validation acc=0.25, validation loss=13.81
# Epoch 13: 58.53s, train acc=0.24, train loss=14.07, validation acc=0.24, validation loss=14.00
# Epoch 14: 62.20s, train acc=0.25, train loss=13.79, validation acc=0.25, validation loss=13.76
# Epoch 15: 69.58s, train acc=0.27, train loss=13.38, validation acc=0.28, validation loss=13.24
# Epoch 16: 77.08s, train acc=0.27, train loss=13.39, validation acc=0.29, validation loss=13.16
# Epoch 17: 84.89s, train acc=0.27, train loss=13.39, validation acc=0.28, validation loss=13.30
# ...
# Epoch 10: 72.22s, train acc=0.96, train loss=0.82, validation acc=0.94, validation loss=1.10
# Epoch 11: 79.79s, train acc=0.96, train loss=0.70, validation acc=0.94, validation loss=1.14
# Epoch 12: 86.26s, train acc=0.98, train loss=0.41, validation acc=0.96, validation loss=0.81
# Epoch 13: 94.36s, train acc=0.98, train loss=0.43, validation acc=0.96, validation loss=0.82
# Epoch 14: 100.84s, train acc=0.97, train loss=0.51, validation acc=0.95, validation loss=0.92
# Epoch 15: 108.53s, train acc=0.98, train loss=0.38, validation acc=0.96, validation loss=0.80
# Epoch 16: 115.13s, train acc=0.98, train loss=0.39, validation acc=0.96, validation loss=0.77
# Epoch 17: 123.12s, train acc=0.98, train loss=0.43, validation acc=0.95, validation loss=0.88
# Epoch 18: 129.68s, train acc=0.98, train loss=0.40, validation acc=0.96, validation loss=0.83
# Epoch 19: 137.75s, train acc=0.98, train loss=0.41, validation acc=0.96, validation loss=0.78
# Epoch 20: 144.26s, train acc=0.99, train loss=0.25, validation acc=0.96, validation loss=0.67
#
# Test acc=0.96, Test loss=0.67
# Optimizer=adam, Activation=leaky_relu, LR=0.01
# Epoch 1: 5.05s, train acc=0.83, train loss=3.10, validation acc=0.83, validation loss=3.20
# Epoch 2: 8.62s, train acc=0.82, train loss=3.27, validation acc=0.82, validation loss=3.31
# Epoch 3: 12.53s, train acc=0.82, train loss=3.24, validation acc=0.82, validation loss=3.32
# Epoch 4: 18.84s, train acc=0.86, train loss=2.50, validation acc=0.86, validation loss=2.65
# Epoch 5: 22.73s, train acc=0.86, train loss=2.51, validation acc=0.86, validation loss=2.64
# Epoch 6: 26.54s, train acc=0.88, train loss=2.27, validation acc=0.88, validation loss=2.24
# Epoch 7: 32.63s, train acc=0.87, train loss=2.38, validation acc=0.86, validation loss=2.51
# Epoch 8: 36.51s, train acc=0.91, train loss=1.75, validation acc=0.90, validation loss=1.84
# Epoch 9: 40.21s, train acc=0.90, train loss=1.88, validation acc=0.89, validation loss=1.94
# Epoch 10: 46.17s, train acc=0.93, train loss=1.34, validation acc=0.92, validation loss=1.54
# Epoch 11: 50.06s, train acc=0.85, train loss=2.80, validation acc=0.84, validation loss=2.93
# Epoch 12: 54.05s, train acc=0.93, train loss=1.37, validation acc=0.92, validation loss=1.50
# Epoch 13: 59.76s, train acc=0.94, train loss=1.16, validation acc=0.92, validation loss=1.41
# Epoch 14: 63.98s, train acc=0.93, train loss=1.31, validation acc=0.92, validation loss=1.50
# Epoch 15: 67.81s, train acc=0.92, train loss=1.54, validation acc=0.91, validation loss=1.74
# Epoch 16: 72.56s, train acc=0.89, train loss=2.10, validation acc=0.87, validation loss=2.32
# Epoch 17: 77.89s, train acc=0.91, train loss=1.58, validation acc=0.90, validation loss=1.89
# Epoch 18: 81.94s, train acc=0.95, train loss=0.99, validation acc=0.93, validation loss=1.26
# Epoch 19: 85.96s, train acc=0.93, train loss=1.21, validation acc=0.92, validation loss=1.41
# Epoch 20: 92.29s, train acc=0.91, train loss=1.60, validation acc=0.90, validation loss=1.85
#
# Test acc=0.90, Test loss=1.85
# Optimizer=adam, Activation=leaky_relu, LR=0.001
# Epoch 1: 4.08s, train acc=0.89, train loss=2.07, validation acc=0.88, validation loss=2.19
# Epoch 2: 7.98s, train acc=0.90, train loss=1.91, validation acc=0.88, validation loss=2.19
# Epoch 3: 14.20s, train acc=0.91, train loss=1.71, validation acc=0.89, validation loss=1.95
# Epoch 4: 18.31s, train acc=0.90, train loss=1.76, validation acc=0.89, validation loss=2.03
# Epoch 5: 22.46s, train acc=0.92, train loss=1.49, validation acc=0.90, validation loss=1.76
# Epoch 6: 29.14s, train acc=0.92, train loss=1.48, validation acc=0.91, validation loss=1.73
# Epoch 7: 32.92s, train acc=0.91, train loss=1.69, validation acc=0.89, validation loss=1.98
# Epoch 8: 36.48s, train acc=0.93, train loss=1.36, validation acc=0.91, validation loss=1.65
# Epoch 9: 43.10s, train acc=0.92, train loss=1.42, validation acc=0.91, validation loss=1.64
# Epoch 10: 47.17s, train acc=0.91, train loss=1.75, validation acc=0.89, validation loss=1.98
# Epoch 11: 51.23s, train acc=0.94, train loss=1.15, validation acc=0.92, validation loss=1.41
# Epoch 12: 57.74s, train acc=0.95, train loss=1.01, validation acc=0.93, validation loss=1.27
# Epoch 13: 61.77s, train acc=0.94, train loss=1.19, validation acc=0.92, validation loss=1.45
# Epoch 14: 65.64s, train acc=0.91, train loss=1.58, validation acc=0.91, validation loss=1.75
# Epoch 15: 71.97s, train acc=0.95, train loss=0.96, validation acc=0.93, validation loss=1.24
# Epoch 16: 76.03s, train acc=0.95, train loss=0.86, validation acc=0.94, validation loss=1.15
# Epoch 17: 80.03s, train acc=0.95, train loss=0.86, validation acc=0.94, validation loss=1.20
# Epoch 18: 85.76s, train acc=0.94, train loss=1.06, validation acc=0.93, validation loss=1.32
# Epoch 19: 90.24s, train acc=0.95, train loss=0.88, validation acc=0.93, validation loss=1.21
# Epoch 20: 94.22s, train acc=0.97, train loss=0.61, validation acc=0.95, validation loss=0.95
#
# Test acc=0.95, Test loss=0.95
# Optimizer=adam, Activation=selu, LR=0.01
# Epoch 1: 6.67s, train acc=0.90, train loss=1.80, validation acc=0.90, validation loss=1.85
# Epoch 2: 11.66s, train acc=0.92, train loss=1.42, validation acc=0.92, validation loss=1.54
# Epoch 3: 16.37s, train acc=0.92, train loss=1.38, validation acc=0.92, validation loss=1.53
# Epoch 4: 23.64s, train acc=0.94, train loss=1.02, validation acc=0.93, validation loss=1.20
# Epoch 5: 28.39s, train acc=0.93, train loss=1.33, validation acc=0.92, validation loss=1.49
# Epoch 6: 34.22s, train acc=0.94, train loss=1.03, validation acc=0.93, validation loss=1.21
# Epoch 7: 39.97s, train acc=0.96, train loss=0.65, validation acc=0.95, validation loss=0.83
# Epoch 8: 44.70s, train acc=0.94, train loss=1.02, validation acc=0.93, validation loss=1.26
# Epoch 9: 51.86s, train acc=0.94, train loss=1.05, validation acc=0.93, validation loss=1.30
# Epoch 10: 56.59s, train acc=0.96, train loss=0.68, validation acc=0.95, validation loss=0.96
# Epoch 11: 61.34s, train acc=0.96, train loss=0.75, validation acc=0.94, validation loss=1.02
# Epoch 12: 68.47s, train acc=0.97, train loss=0.54, validation acc=0.96, validation loss=0.80
# Epoch 13: 73.10s, train acc=0.97, train loss=0.55, validation acc=0.96, validation loss=0.81
# Epoch 14: 78.94s, train acc=0.98, train loss=0.42, validation acc=0.96, validation loss=0.77
# Epoch 15: 84.90s, train acc=0.98, train loss=0.38, validation acc=0.96, validation loss=0.69
# Epoch 16: 89.81s, train acc=0.98, train loss=0.40, validation acc=0.96, validation loss=0.72
# Epoch 17: 96.92s, train acc=0.98, train loss=0.45, validation acc=0.96, validation loss=0.75
# Epoch 18: 101.59s, train acc=0.98, train loss=0.42, validation acc=0.96, validation loss=0.75
# Epoch 19: 106.86s, train acc=0.97, train loss=0.46, validation acc=0.96, validation loss=0.72
# Epoch 20: 113.24s, train acc=0.97, train loss=0.49, validation acc=0.96, validation loss=0.77
#
# Test acc=0.96, Test loss=0.77
# Optimizer=adam, Activation=selu, LR=0.001
# Epoch 1: 4.80s, train acc=0.91, train loss=1.74, validation acc=0.90, validation loss=1.91
# Epoch 2: 11.29s, train acc=0.91, train loss=1.61, validation acc=0.90, validation loss=1.81
# Epoch 3: 16.26s, train acc=0.94, train loss=1.16, validation acc=0.92, validation loss=1.41
# Epoch 4: 21.04s, train acc=0.93, train loss=1.22, validation acc=0.92, validation loss=1.49
# Epoch 5: 28.30s, train acc=0.94, train loss=1.04, validation acc=0.93, validation loss=1.31
# Epoch 6: 32.96s, train acc=0.95, train loss=0.88, validation acc=0.94, validation loss=1.19
# Epoch 7: 38.73s, train acc=0.95, train loss=0.92, validation acc=0.94, validation loss=1.19
# Epoch 8: 44.58s, train acc=0.95, train loss=0.84, validation acc=0.94, validation loss=1.12
# Epoch 9: 49.23s, train acc=0.94, train loss=1.09, validation acc=0.92, validation loss=1.42
# Epoch 10: 56.09s, train acc=0.95, train loss=0.94, validation acc=0.93, validation loss=1.30
# Epoch 11: 60.78s, train acc=0.96, train loss=0.76, validation acc=0.94, validation loss=1.17
# Epoch 12: 65.56s, train acc=0.97, train loss=0.57, validation acc=0.95, validation loss=0.97
# Epoch 13: 72.81s, train acc=0.97, train loss=0.50, validation acc=0.95, validation loss=0.89
# Epoch 14: 77.67s, train acc=0.95, train loss=0.96, validation acc=0.93, validation loss=1.28
# Epoch 15: 83.45s, train acc=0.97, train loss=0.61, validation acc=0.95, validation loss=0.97
# Epoch 16: 89.13s, train acc=0.93, train loss=1.34, validation acc=0.91, validation loss=1.68
# Epoch 17: 93.87s, train acc=0.96, train loss=0.70, validation acc=0.94, validation loss=1.03
# Epoch 18: 101.20s, train acc=0.97, train loss=0.58, validation acc=0.95, validation loss=0.97
# Epoch 19: 106.00s, train acc=0.97, train loss=0.51, validation acc=0.95, validation loss=0.97
# Epoch 20: 111.21s, train acc=0.98, train loss=0.36, validation acc=0.95, validation loss=0.83
#
# Test acc=0.95, Test loss=0.83
# Optimizer=adam, Activation=elu, LR=0.01
# Epoch 1: 6.32s, train acc=0.89, train loss=2.05, validation acc=0.88, validation loss=2.20
# Epoch 2: 10.86s, train acc=0.92, train loss=1.40, validation acc=0.92, validation loss=1.56
# Epoch 3: 17.11s, train acc=0.93, train loss=1.21, validation acc=0.93, validation loss=1.35
# Epoch 4: 22.20s, train acc=0.95, train loss=1.01, validation acc=0.94, validation loss=1.12
# Epoch 5: 26.86s, train acc=0.95, train loss=0.89, validation acc=0.95, validation loss=1.00
# Epoch 6: 33.78s, train acc=0.96, train loss=0.81, validation acc=0.94, validation loss=1.03
# Epoch 7: 38.17s, train acc=0.95, train loss=0.84, validation acc=0.94, validation loss=1.06
# Epoch 8: 42.96s, train acc=0.95, train loss=0.85, validation acc=0.94, validation loss=1.06
# Epoch 9: 49.40s, train acc=0.96, train loss=0.74, validation acc=0.95, validation loss=0.95
# Epoch 10: 53.92s, train acc=0.96, train loss=0.76, validation acc=0.95, validation loss=0.99
# Epoch 11: 59.50s, train acc=0.97, train loss=0.62, validation acc=0.95, validation loss=0.87
# Epoch 12: 65.16s, train acc=0.96, train loss=0.72, validation acc=0.95, validation loss=0.95
# Epoch 13: 69.73s, train acc=0.94, train loss=1.05, validation acc=0.93, validation loss=1.30
# Epoch 14: 75.74s, train acc=0.98, train loss=0.44, validation acc=0.96, validation loss=0.71
# Epoch 15: 80.63s, train acc=0.98, train loss=0.38, validation acc=0.96, validation loss=0.70
# Epoch 16: 85.24s, train acc=0.97, train loss=0.47, validation acc=0.96, validation loss=0.75
# Epoch 17: 92.44s, train acc=0.98, train loss=0.39, validation acc=0.96, validation loss=0.68
# Epoch 18: 96.92s, train acc=0.98, train loss=0.37, validation acc=0.96, validation loss=0.65
# Epoch 19: 101.19s, train acc=0.98, train loss=0.44, validation acc=0.96, validation loss=0.80
# Epoch 20: 107.99s, train acc=0.97, train loss=0.50, validation acc=0.96, validation loss=0.75
#
# Test acc=0.96, Test loss=0.75
# Optimizer=adam, Activation=elu, LR=0.001
# Epoch 1: 4.78s, train acc=0.92, train loss=1.43, validation acc=0.91, validation loss=1.67
# Epoch 2: 10.97s, train acc=0.94, train loss=1.03, validation acc=0.93, validation loss=1.31
# Epoch 3: 16.28s, train acc=0.95, train loss=0.97, validation acc=0.93, validation loss=1.23
# Epoch 4: 20.69s, train acc=0.96, train loss=0.75, validation acc=0.94, validation loss=1.06
# Epoch 5: 27.67s, train acc=0.95, train loss=0.84, validation acc=0.94, validation loss=1.12
# Epoch 6: 32.05s, train acc=0.96, train loss=0.78, validation acc=0.94, validation loss=1.07
# Epoch 7: 36.89s, train acc=0.96, train loss=0.71, validation acc=0.95, validation loss=1.00
# Epoch 8: 43.96s, train acc=0.97, train loss=0.61, validation acc=0.95, validation loss=0.94
# Epoch 9: 48.56s, train acc=0.97, train loss=0.52, validation acc=0.95, validation loss=0.85
# Epoch 10: 54.38s, train acc=0.98, train loss=0.43, validation acc=0.95, validation loss=0.83
# Epoch 11: 60.06s, train acc=0.97, train loss=0.62, validation acc=0.95, validation loss=0.99
# Epoch 12: 64.70s, train acc=0.96, train loss=0.83, validation acc=0.94, validation loss=1.09
# Epoch 13: 71.58s, train acc=0.97, train loss=0.46, validation acc=0.96, validation loss=0.81
# Epoch 14: 76.41s, train acc=0.98, train loss=0.43, validation acc=0.96, validation loss=0.75
# Epoch 15: 80.90s, train acc=0.98, train loss=0.40, validation acc=0.96, validation loss=0.75
# Epoch 16: 88.19s, train acc=0.97, train loss=0.51, validation acc=0.95, validation loss=0.88
# Epoch 17: 92.90s, train acc=0.98, train loss=0.39, validation acc=0.96, validation loss=0.76
# Epoch 18: 98.50s, train acc=0.97, train loss=0.54, validation acc=0.95, validation loss=0.95
# Epoch 19: 104.35s, train acc=0.98, train loss=0.31, validation acc=0.96, validation loss=0.70
# Epoch 20: 109.17s, train acc=0.98, train loss=0.37, validation acc=0.96, validation loss=0.75
#
# Test acc=0.96, Test loss=0.75
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=tanh, LR=0.001 -> Acc=0.96, Loss=0.67
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=elu, LR=0.001 -> Acc=0.96, Loss=0.75
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=elu, LR=0.01 -> Acc=0.96, Loss=0.75
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=selu, LR=0.01 -> Acc=0.96, Loss=0.77
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=selu, LR=0.001 -> Acc=0.95, Loss=0.83
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=tanh, LR=0.01 -> Acc=0.95, Loss=0.84
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=sigmoid, LR=0.01 -> Acc=0.95, Loss=0.95
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=sigmoid, LR=0.001 -> Acc=0.95, Loss=0.95
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=leaky_relu, LR=0.001 -> Acc=0.95, Loss=0.95
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=selu, LR=0.01 -> Acc=0.91, Loss=1.73
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=leaky_relu, LR=0.01 -> Acc=0.90, Loss=1.85
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=selu, LR=0.01 -> Acc=0.90, Loss=1.90
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=elu, LR=0.01 -> Acc=0.90, Loss=1.93
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=tanh, LR=0.01 -> Acc=0.89, Loss=1.98
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=elu, LR=0.01 -> Acc=0.89, Loss=1.98
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=tanh, LR=0.01 -> Acc=0.89, Loss=2.01
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=relu, LR=0.01 -> Acc=0.87, Loss=2.33
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=leaky_relu, LR=0.01 -> Acc=0.86, Loss=2.53
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=selu, LR=0.001 -> Acc=0.86, Loss=2.59
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=selu, LR=0.001 -> Acc=0.86, Loss=2.62
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=leaky_relu, LR=0.01 -> Acc=0.85, Loss=2.81
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=tanh, LR=0.001 -> Acc=0.84, Loss=2.97
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=elu, LR=0.001 -> Acc=0.84, Loss=2.97
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=elu, LR=0.001 -> Acc=0.84, Loss=3.03
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=tanh, LR=0.001 -> Acc=0.83, Loss=3.14
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=sigmoid, LR=0.01 -> Acc=0.83, Loss=3.18
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=relu, LR=0.01 -> Acc=0.81, Loss=3.48
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=sigmoid, LR=0.01 -> Acc=0.80, Loss=3.69
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=relu, LR=0.001 -> Acc=0.76, Loss=4.34
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=relu, LR=0.001 -> Acc=0.74, Loss=4.82
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=leaky_relu, LR=0.001 -> Acc=0.74, Loss=4.85
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=relu, LR=0.001 -> Acc=0.71, Loss=5.26
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=leaky_relu, LR=0.001 -> Acc=0.71, Loss=5.29
# Arch=[784, 128, 64, 10], Optimizer=momentum, Activation=sigmoid, LR=0.001 -> Acc=0.55, Loss=8.20
# Arch=[784, 128, 64, 10], Optimizer=sgd, Activation=sigmoid, LR=0.001 -> Acc=0.54, Loss=8.42
# Arch=[784, 128, 64, 10], Optimizer=adam, Activation=relu, LR=0.01 -> Acc=0.30, Loss=12.92

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

def relu_approximation(input_data, target_labels):
    """
    Approximates a sine function using ReLU activations.

    Args:
        input_data: torch.tensor
            Input training data points.
        target_labels: torch.tensor
            Ground truth labels for the training data points.

    Returns:
        predicted_labels: torch.tensor
            Predicted output labels using ReLU approximation.
        activation_map: torch.tensor
            ReLU activation values across the x-axis.
        x_points: torch.tensor
            Dense points along the x-axis for visualization.
    """
    num_relus = input_data.shape[0] - 1

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    biases = ((input_data[:-1] + input_data[1:]) / 2).view(-1, 1)

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, x_points.shape[0])  # num_relus rows, x_points columns (1000 points)

    # Compute ReLU activations for each segment
    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    # Initialize weights for the ReLU units
    relu_weights = torch.zeros(num_relus)

    # Compute weights based on differences in target slopes
    previous_slope = 0
    for relu_idx in range(num_relus):
        current_slope = (target_labels[relu_idx + 1] - target_labels[relu_idx]) / (
            input_data[relu_idx + 1] - input_data[relu_idx]
        )
        relu_weights[relu_idx] = current_slope - previous_slope
        previous_slope = current_slope

    # Compute predicted labels as a weighted sum of ReLU activations
    predicted_labels = torch.matmul(relu_weights, activation_map)

    return predicted_labels, activation_map, x_points

def plot_function_apx(x_points, activation_map, predicted_output, input_data, target_labels):
    plt.figure(figsize=(10, 6))

    plt.plot(input_data.numpy(), target_labels.numpy(), "o", label="Ground Truth (Sine Function)",linewidth=2)

    plt.plot(x_points.numpy(), predicted_output.numpy(), label="ReLU Approximation", linewidth=2)

    for i in range(activation_map.shape[0]):
        plt.plot(x_points.numpy(), activation_map[i, :].numpy(), '--', label=f"ReLU {i+1}")

    plt.title("Function Approximation Using ReLU")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.grid(True)
    plt.show()

# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

# Approximate the function using ReLU activations
predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)

# Plot both the approximation and the ground truth together
plot_function_apx(x_points, activation_map, predicted_output, input_data, target_labels)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i, hidden_units in enumerate(hidden_unit_nums):
        hidden_layer = nn.Linear(in_num, hidden_units)
        self.mlp.add_module(f'Hidden_Layer_{i+1}', hidden_layer)
        if activation_fn == 'relu':
             activation = nn.ReLU()
        elif activation_fn == 'sigmoid':
             activation = nn.Sigmoid()
        elif activation_fn == 'tanh':
             activation = nn.Tanh()
        elif activation_fn == 'leaky_relu':
             activation = nn.LeakyReLU()
        else:
                raise ValueError(f"Unsupported activation function: {activation_fn}")

        self.mlp.add_module(f'Activation_{i+1}', activation)
            # Update in_num for the next layer
        in_num = hidden_units

    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
from sklearn.preprocessing import PolynomialFeatures
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    poly = PolynomialFeatures(degree=poly_degree, include_bias=False)
    poly_X = poly.fit_transform(X.numpy())  # Convert to numpy for sklearn compatibility

        # Return as a torch tensor
    poly_X = torch.tensor(poly_X, dtype=torch.float32)

    num_features = poly_X.shape[1]

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize? Making polynomial regression for dataset and train on it then fit it to make better result.

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 69.94
# Accuracy on the 800 testing samples: 69.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?Result is better then wide network because when we have 128 neurons we can train and update weights faster than and we can use power of activation functions to get better result.accuray is noticeably better than previous format

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2_deep = MLP_pytorch('relu',2 , [128], K)
criterion2 = nn.CrossEntropyLoss()
optimizer2 = optim.Adam(net2_deep.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2_deep, criterion2, optimizer2,train_loader,
                                   test_loader,
                                   num_epochs=100)

X_all = sample_grid()
y_pred = net2_deep(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.75
# Accuracy on the 800 testing samples: 98.00
